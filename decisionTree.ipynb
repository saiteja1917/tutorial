# %% [markdown]
# <a href="https://colab.research.google.com/github/saiteja1917/tutorial/blob/main/decisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
df=load_iris()
x=df.data
y=df.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
s=model.score(x_test,y_test)
print(s)
r=model.predict([[6.7,3.0,5.2,2.3]])
print(r)
if r==0:
    print("setosa")
elif r==1:
    print("versicolor")
else:
    print("virginica")
# Out:
# 1.0
# [2]
# virginica

# %%
# prompt: generate  graph for above one

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plot_tree(model, feature_names=df.feature_names, class_names=df.target_names, filled=True)
plt.show()
